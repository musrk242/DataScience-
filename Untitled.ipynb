# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
df=pd.read_excel(r'C:\Users\jyothi\Downloads\Sample - Superstore.xlsx')
df=df[['Order Date','Sales']].sort_values('Order Date',ascending=False)
df= df.rename(columns={'Order Date': 'od', 'Sales': 'sales'})
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#f=plt.figure(figsize=(25,5))
plt.plot(df.od,df.sales)
plt.xlabel('od');
plt.ylabel('sales')
plt.title('sales by date')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-5de26026834d> in <module>()
#       3 #f=plt.figure(figsize=(25,5))
#       4 plt.plot(df.od,df.sales)
# ----> 5 plt.xlabel('od');
#       6 plt.ylabel('sales')
#       7 plt.title('sales by date')
#
# TypeError: 'str' object is not callable
